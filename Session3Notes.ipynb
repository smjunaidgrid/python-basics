# %%
'hello'
# Out:
# 'hello'

# %%
"Hey checking with Jupyter Notebook"
# Out:
# 'Hey checking with Jupyter Notebook'

# %%
d = {'k1': 100, 'k2':200}
d
# Out:
# {'k1': 100, 'k2': 200}

# %%
d['k3'] = 300
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}

# %%
#Sets
myset = set()
myset
# Out:
# set()

# %%
myset.add(1)
myset
# Out:
# {1}

# %%
myset.add(5)
myset
# Out:
# {1, 5}

# %%
myset.add(2)
myset
# Out:
# {1, 2, 5}

# %%
mylist = [1,2,3,4,5,5,5,8,8,7,7]
mylist
# Out:
# [1, 2, 3, 4, 5, 5, 5, 8, 8, 7, 7]

# %%
set[mylist]
# Out:
# set[[1, 2, 3, 4, 5, 5, 5, 8, 8, 7, 7]]

# %%
set(mylist)
# Out:
# {1, 2, 3, 4, 5, 7, 8}

# %%
# %%writefile myfile.txt
# Hello, checking withh the files inn python - jupyter notesbooks
# This is the second line
# The third line
# The fourth
# Out:
# Overwriting myfile.txt

# %%
myfile = open ('myfile.txt')

# %%
myfile = open ('nofileexist.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 myfile = open ('nofileexist.txt')
#
# File ~/Library/Python/3.14/lib/python/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nofileexist.txt'

# %%
pwd
# Out:
# '/Users/moshaik/Desktop/Dev01'

# %%
myfile.read()
# Out:
# 'Hello, checking withh the files inn python - jupyter notesbooks \nThis is the second line\nThe third line\nThe fourth\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello, checking withh the files inn python - jupyter notesbooks \n'

# %%
myfile.seek(0)
InMyFile = myfile.read()

# %%
InMyFile
# Out:
# 'Hello, checking withh the files inn python - jupyter notesbooks \nThis is the second line\nThe third line\nThe fourth\n'

# %%
myfile.readlines()
# Out:
# ['Hello, checking withh the files inn python - jupyter notesbooks \n',
#  'This is the second line\n',
#  'The third line\n',
#  'The fourth\n']

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello, checking withh the files inn python - jupyter notesbooks \nThis is the second line\nThe third line\nThe fourth\n'

# %%
with open('myfile.txt', mode='r') as file:
    cont = file.read()

# %%
cont
# Out:
# 'Hello, checking withh the files inn python - jupyter notesbooks \nThis is the second line\nThe third line\nThe fourth\n'

# %%
# %%writefile harrypotter.txt
# 1. The Colors of the sky fade with the setting sun
# 2. There will be no foolish wand waving or silly incantations in this class...
# 3. Avada Kedavra..!
# Out:
# Overwriting harrypotter.txt

# %%
with open('harrypotter.txt', mode = 'r') as f:
    print(f.read())
# Out:
# 1. The Colors of the sky fade with the setting sun
# 2. There will be no foolish wand waving or silly incantations in this class...
# 3. Avada Kedavra..!
# 4. Manifest each step

# %%
with open('harrypotter.txt',mode = 'a') as f:
    f.write("4. Manifest each step")

# %%
with open('newf.txt',mode = 'w') as f:
    f.write("new file is created!")

# %%
with open('newf.txt',mode = 'r') as f:
    print(f.read())
# Out:
# new file is created!

# %%
pwd
# Out:
# '/Users/moshaik/Desktop/Dev01'
