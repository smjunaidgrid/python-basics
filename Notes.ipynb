# %%
'hello'
# Out:
# 'hello'

# %%
"Hey checking with Jupyter Notebook"
# Out:
# 'Hey checking with Jupyter Notebook'

# %%
d = {'k1': 100, 'k2':200}
d
# Out:
# {'k1': 100, 'k2': 200}

# %%
d['k3'] = 300
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}
