# %%
"Hello"
# Out:
# 'Hello'

# %%
# PIL Library - Python Imaging Library

# %%
from PIL import Image 
mac = Image.open('example.jpg')

# %%
import os
print(os.getcwd())
# Out:
# /Users/moshaik/Desktop/Dev01/ImagesWithPython/14-Working-with-Images

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.show()

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.crop((800,800,1200,1200))
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
pencils = Image.open('pencils.jpg')

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300>

# %%
pencils.size
# Out:
# (1950, 1300)
