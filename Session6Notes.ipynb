# %%
mylist = ['1','2','3']

# %%
help(mylist.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
help(mylist.copy)
# Out:
# Help on built-in function copy:
#
# copy() method of builtins.list instance
#     Return a shallow copy of the list.

# %%
from platform import python_version
print(python_version())
# Out:
# 3.14.2

# %%
def name_pass(name):
    print(f"Hello {name} Welcome to Grid Dynamics!")

# %%
name_pass("Junaid")
# Out:
# Hello Junaid Welcome to Grid Dynamics!

# %%
def sum_nums(a,b):
    return a+b

# %%
res = sum_nums(10,20)

# %%
res
# Out:
# 30

# %%
sum_nums(10,30.5)
# Out:
# 40.5

# %%
#Check if number is even
def even(num):
    return num%2 == 0

# %%
even(2)
# Out:
# True

# %%
even(3)
# Out:
# False

# %%
# Return true if the any number is even inside the list 
def checklist(mylist):
    for num in mylist:
        if num%2==0:
            return True
        else:
            pass
    return False

# %%
checklist([1,2,6,8,14,15,17,12,5])
# Out:
# True

# %%
# Return true if the any number is even inside the list 
def checklist(mylist):
    even_nums = []
    for num in mylist:
        if num%2==0:
            even_nums.append(num)
        else:
            pass
    return even_nums

# %%
work_hours = [('tom',2749),('jerry',2929),('peter',2439),('harry',2123),('ron',2789)]

# %%
# Which employee has more working hours 

def employee_hrs(work_hours):
    curr_hrs = 0
    employee_of_month = ''
    for employees,hours in work_hours:
        if hours > curr_hrs:
            curr_hrs = hours
            employee_of_month = employees
        else:
            pass
    return (employee_of_month,curr_hrs)

# %%
employee_hrs(work_hours)
# Out:
# ('jerry', 2929)

# %%
# Match the Location through user CLI input
from random import shuffle
def shuffle_list(mylist):
    shuffle(mylist)
    return mylist
mylist = [' ',' ','O']

# %%
shuffle_list(mylist)
# Out:
# [' ', 'O', ' ']

# %%
def player_guess():
    guess = '' 
    while guess not in ['0','1','2']:
        guess = int(input("Enter position of guess 0,1 or 2"))
    return guess

# %%
#*args and kwargs
def myfunc(*args):
    return sum(args)*0.05

# %%
myfunc(100,200,300,400,100)
# Out:
# 55.0

# %%
def animal(text):
    worldlist = text.lower().split()
    print(worldlist)

    return worldlist[0][0]==worldlist[1][0]

# %%
animal('Arithemic addition')
# Out:
# ['arithemic', 'addition']
# True

# %%
# capitalize stuff
def old(name):
    first_half=name[:3].capitalize()
    second_half=name[3:].capitalize()
    return first_half+second_half

# %%
old('macdonald')
# Out:
# 'MacDonald'

# %%
'hello'.capitalize()
# Out:
# 'Hello'

# %%
# Reverse
def mas(text):
    worldlist = text.split()
    worldlist = worldlist[::-1]
    return ' '.join(worldlist)

# %%
mas('Iam Ironman')
# Out:
# 'Ironman Iam'

# %%
def checkabs(num):
    ret = abs(num)
    return ret

# %%
checkabs(-926)
# Out:
# 926

# %%
def has_3(num):
    for i in range(0,len(num)-1):
        if num[i] == 3 and num[i+1] == 3:
            return True
    return False

# %%
has_3([1,2,3,4,5,3])
# Out:
# False

# %%
has_4([1,2,3,4,5,4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[267], line 1
# ----> 1 has_4([1,2,3,4,5,4])
#
# NameError: name 'has_4' is not defined

# %%
# Return the sum of the numbers in the array, except ignore sections of numbers starting with a 6 and extending to the next 9(every 6 will be followed by at least one 9). Return 0 for no numbers 
def summer_69(arr):
    total = 0 
    add = True
    for num in arr:
        while add:
            if num != 6:
                total += num
                break
            else:
                add = False
        while not add:
            if num != 9:
                break
            else:
                add = True
                break
    return total

# %%
summer_69([1,2,3,6,3,4,5,9])
# Out:
# 6

# %%
def spygame(num):
    code = [0,0,7,'X']

    for nums in num:
        if nums == code[0]:
            code.pop(0)
    return len(code) == 1

# %%
spygame([1, 0, 2,4, 7, 5])
# Out:
# False

# %%
spygame([0,0,7])
# Out:
# True

# %%
# CounPrime 
def CountPrime(nums):
    primelist = []
    for num in nums:
        if num <= 2:
            continue
        else:
            for num in range(3,x,2):
                prime = True
                for i in range(3,(int(num**.5)+1)):
                    if num % i == 0:
                        prime = False
                if prime:
                    primelist.append(num)
    return len(primelist)

# %%
#Count Primes 
def checkprimes(num):
    if num <= 2:
        return 0
    primes = [2]

    x = 3 
    while x<=num:
        for y in range(3,x,2):
            if x%y == 0:
                x+=2
                break
        else:
            primes.append(x)
            x += 2
    print(primes)

# %%
checkprimes(15)
# Out:
# [2, 3, 5, 7, 11, 13] check2

# %%
#Count Primes 
def checkprimes(num):
    if num <= 2:
        return 0
    primes = [2]

    x = 3 
    while x<=num:
        for y in primes:
            if x%y == 0:
                x+=2
                break
        else:
            primes.append(x)
            x += 2
    print(primes,"check2")
    
# EULER Problems

# %%
# 60 - Lambda Expressions

def square(num):
    return num**2

# %%
my_nums= [1,2,3,4,5,6,7]

# %%
list(map(square,my_nums))
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
# Splicer
def splicer(mystring):
    if len(mystring)%2 == 0:
        return "EVEN"
    else:
        return mystring[0]

# %%
splicer("Hello World")
# Out:
# 'H'

# %%
names = ['Grid','Book','Pen','Laptop','Car']

# %%
list(map(splicer,names))
# Out:
# ['EVEN', 'EVEN', 'P', 'EVEN', 'C']

# %%
#filter
def check_even(num):
    return num%2==0

# %%
my_num = [1,2,3,4,5,6]

# %%
list(filter(check_even,my_num))
# Out:
# [2, 4, 6]

# %%
list(map(lambda num : num**2,my_num))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
list(map(lambda x:x[::-1],names))
# Out:
# ['dirG', 'kooB', 'neP', 'potpaL', 'raC']

# %%
list(map(lambda x:x[1],names))
# Out:
# ['r', 'o', 'e', 'a', 'a']

# %%
def ran_check(num,low,high):
    return num in range(low,high+1)

# %%
ran_check(8,2,10)
# Out:
# True

# %%
def up_low(s):
    lowercase = 0
    uppercase = 0
    for char in s:
        if char.isupper():
            uppercase += 1
        elif char.islower():
            lowercase += 1
        else:
            pass
    print(f"The string {s}")    
    print(f"The count of lowercase = {lowercase}")
    print(f"The count of uppercase = {uppercase}")

# %%
up_low("Good Morning Team, Hope the projects met the deadlines")
# Out:
# The string Good Morning Team, Hope the projects met the deadlines
# The count of lowercase = 41
# The count of uppercase = 4

# %%
#dict impl

def up_lo(s):
    d =  {'upper':0,'lower':0}
    for char in s:
        if char.isupper():
            d['upper'] += 1
        elif char.islower():
            d['lower'] += 1
        else:
            pass
    print(f"The string {s}")    
    print(f"The count of lowercase = {d['lower']}")
    print(f"The count of uppercase = {d['upper']}")

# %%
up_lo("Good Morning Team, Hope the projects met the deadlines")
# Out:
# The string Good Morning Team, Hope the projects met the deadlines
# The count of lowercase = 41
# The count of uppercase = 4

# %%
# uniques
def unqlist(lst):
    seennum = []
    for num in lst:
        if num not in seennum:
            seennum.append(num)
    return seennum

# %%
unqlist([1,1,1,2,2,3,4,4,5,7,2,1,9,8,6])
# Out:
# [1, 2, 3, 4, 5, 7, 9, 8, 6]

# %%
def multiply(num):
    total = 1
    for n in num:
        total = total * n
    return total

# %%
multiply([1,3,4])
# Out:
# 12

# %%
def palindrome(s):
    s= s.replace(' ','').lower()
    return s[::-1] == s

# %%
palindrome('MaDam')
# Out:
# True

# %%
x = '10' 
x.isdigit()
# Out:
# True

# %%
def user_choice():
    ch = "W"
    while ch.isdigit() == False:
        ch = input("Enter a digit (1-10): ")
        if ch.isdigit() == False:
            print(f"Sorry '{ch}' is not a digit, ") 
    return int(ch)

# %%
user_choice()
# Out:
# Sorry perfect 7 is not a digit,
# 99

# %%
#Rewrite the loooooooooop!
def user_choice1():
    ch = "W"
    accp_range = range(1,11)
    win_range = False
    while ch.isdigit() == False or win_range == False:
        ch = input("Enter a digit (1-10): ")
        if ch.isdigit() == False:
            print(f"Sorry '{ch}' is not a digit") 
        if ch.isdigit() == True:
            if int(ch) in accp_range:
                win_range == True
            else:
                print("digit not in the range")
                win_range == False
    return int(ch)

# %%
user_choice1()
# Out:
# Sorry '' is not a digit
# Sorry 'de' is not a digit
# Sorry 'aed' is not a digit
# digit not in the range
# digit not in the range
# digit not in the range

# %%
game_list = [0,1,2]

# %%
def display_game(game_list):
    print("Here is the current list")
    print(game_list)

# %%
display_game(game_list)
# Out:
# Here is the current list
# [0, 1, 2]

# %%
def position_choice():
    
    # This original choice value can be anything that isn't an integer
    choice = 'wrong'
    
    # While the choice is not a digit, keep asking for input.
    while choice not in ['0','1','2']:
        
        # we shouldn't convert here, otherwise we get an error on a wrong input
        choice = input("Pick a position to replace (0,1,2): ")
        
        if choice not in ['0','1','2']:
            # THIS CLEARS THE CURRENT OUTPUT BELOW THE CELL
            clear_output()
            
            print("Sorry, but you did not choose a valid position (0,1,2)")
            
    
    # Optionally you can clear everything after running the function
    # clear_output()
    
    # We can convert once the while loop above has confirmed we have a digit.
    return int(choice)

# %%
def replacement_choice(game_list,position):
    
    user_placement = input("Type a string to place at the position")
    
    game_list[position] = user_placement
    
    return game_list

# %%
def gameon_choice():
    
    # This original choice value can be anything that isn't a Y or N
    choice = 'wrong'
    
    # While the choice is not a digit, keep asking for input.
    while choice not in ['Y','N']:
        
        # we shouldn't convert here, otherwise we get an error on a wrong input
        choice = input("Would you like to keep playing? Y or N ")

        
        if choice not in ['Y','N']:
            # THIS CLEARS THE CURRENT OUTPUT BELOW THE CELL
            clear_output()
            
            print("Sorry, I didn't understand. Please make sure to choose Y or N.")
            
    
    # Optionally you can clear everything after running the function
    # clear_output()
    
    if choice == "Y":
        # Game is still on
        return True
    else:
        # Game is over
        return False

# %%
# Variable to keep game playing
game_on = True

# First Game List
game_list = [0,1,2]



while game_on:
    
    # Clear any historical output and show the game list
    clear_output()
    display_game(game_list)
    
    # Have player choose position
    position = position_choice()
    
    # Rewrite that position and update game_list
    game_list = replacement_choice(game_list,position)
    
    # Clear Screen and show the updated game list
    clear_output()
    display_game(game_list)
    
    # Ask if you want to keep playing
    game_on = gameon_choice()
# Out:
# Here is the current list
# [0, 1, 2]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[271], line 16
#      13 display_game(game_list)
#      15 # Have player choose position
# ---> 16 position = position_choice()
#      18 # Rewrite that position and update game_list
#      19 game_list = replacement_choice(game_list,position)
#
# Cell In[11], line 14, in position_choice()
#      10     choice = input("Pick a position to replace (0,1,2): ")
#      12     if choice not in ['0','1','2']:
#      13         # THIS CLEARS THE CURRENT OUTPUT BELOW THE CELL
# ---> 14         clear_output()
#      16         print("Sorry, but you did not choose a valid position (0,1,2)")
#      19 # Optionally you can clear everything after running the function
#      20 # clear_output()
#      21
#      22 # We can convert once the while loop above has confirmed we have a digit.
#
# NameError: name 'clear_output' is not defined
