# %%
# Decorators

# %%
def func():
    return 1

# %%
func()
# Out:
# 1

# %%
func
# Out:
# <function __main__.func()>

# %%
def Hello():
    return "Hellooo!"

# %%
Hello()
# Out:
# 'Hellooo!'

# %%
greet = Hello

# %%
greet()
# Out:
# 'Hellooo!'

# %%
del Hello

# %%
Hello()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Hello()
#
# NameError: name 'Hello' is not defined

# %%
greet()
# Out:
# 'Hellooo!'

# %%
def hello(name = "Junaid"):
    print("The hello() function is been executed")

    def greet():
        print("This is a greet function")
    
    def welcome():
        print("This is a welcome() function")
    
    if name == "Junaid":
        return greet
    else:
        return welcome

    print("This is the end of hello func")

# %%
newfunc = hello("Junaid")
# Out:
# The hello() function is been executed

# %%
print(newfunc())
# Out:
# This is a greet function
# None

# %%
newfunc()
# Out:
# This is a greet function

# %%
def cool():

    print("This is cool")

    def supercool():
        return "This is super cool"
    
    def chill():
        return "This is super chill"
    return chill
    return supercool

# %%
cool()
# Out:
# This is cool
# <function __main__.cool.<locals>.chill()>

# %%
some_func = cool()
# Out:
# This is cool

# %%
some_func()
# Out:
# 'This is super chill'
